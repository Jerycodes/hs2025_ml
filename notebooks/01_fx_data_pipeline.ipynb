# %% [markdown]
# # 📈 FX Data Pipeline — Projekt „hs2025_ml“
#
# ### 🎯 Ziel des Projekts
# Vorhersage signifikanter Kursbewegungen (z. B. EUR/USD) innerhalb definierter Zeiträume
# auf Basis von Finanz- und Nachrichtenquellen (RSS-Feeds, Artikel).
#
# ---
#
# ### ⚙️ Aktueller Stand (bis jetzt)
# 1. Projektstruktur erstellt (`data/`, `db/`, `src/`, `notebooks/`, usw.)
# 2. Virtuelle Umgebung aktiviert und GitHub verbunden
# 3. SQLite-Datenbank `fx_project.sqlite` mit Tabelle `fx_rates` angelegt
# 4. Klasse `FXDataLoader` entwickelt
# 5. `download()` & `upsert()` erfolgreich getestet
#
# ---
#
# ### 📓 Aufbau dieses Notebooks
# 1. Setup & Imports
# 2. `FXDataLoader`-Smoke-Test
# 3. Download-Demonstration (`EURUSD=X`)
# 4. Insert-Demonstration
# 5. Ergebnisprüfung in SQLite
# 6. Notizen / To-dos
